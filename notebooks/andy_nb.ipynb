# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rl_control.wave_gen import generate_wave_train
import seaborn as sns
import numpy as np

# %%
sim_time=60
ramp_time=15
time_step=0.1

# %%
wave_train, surge, heave, pitch = generate_wave_train(2.5, 5, 3)
sns.lineplot(wave_train)
# Out:
# <Axes: >

# %%
sns.lineplot([surge,heave,pitch])
# Out:
# <Axes: >

# %%
type(surge)
# Out:
# list
