# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rl_control.wave_gen import generate_wave_train
import seaborn as sns
import numpy as np

# %%
Tp_range = [5.0, 7.5, 10.0]

# %%
sim_time=20
ramp_time=2
time_step=0.1
Hs = 3.5
Tp = 5.0

# %%
seed = 19

# %%
heaves = []
for Tp in Tp_range:
    wave_train, surge, heave, pitch = generate_wave_train(Hs, Tp, seed, sim_time=sim_time, ramp_time=ramp_time)
    heaves.append(heave)

sns.lineplot(heaves)
# Out:
# <Axes: >

# %%
seed = 20

# %%
wave_train, surge, heave, pitch = generate_wave_train(Hs, Tp, seed, sim_time=sim_time, ramp_time=ramp_time)
sns.lineplot([surge,heave,pitch])
# Out:
# <Axes: >

# %%
sns.lineplot(wave_train)
# Out:
# <Axes: >

# %%
type(surge)
# Out:
# list
