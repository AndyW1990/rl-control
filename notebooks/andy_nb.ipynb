# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rl_control.wave_gen import generate_wave_train
import seaborn as sns
import numpy as np

# %%
sim_time=20
ramp_time=5
time_step=0.1
Hs = 2.5
Tp = 6.0

# %%
seed = 1

# %%
seed = 18

# %%
wave_train, surge, heave, pitch = generate_wave_train(Hs, Tp, seed, ramp_time=ramp_time)
sns.lineplot([surge,heave,pitch])
# Out:
# <Axes: >

# %%
sns.lineplot(wave_train)
# Out:
# <Axes: >

# %%
type(surge)
# Out:
# list
