# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rl_control.wave_gen import generate_wave_train
import seaborn as sns
import numpy as np

# %%
sim_time=60
ramp_time=10
time_step=0.1

# %%
wave_train, surge, heave, pitch = generate_wave_train(1.5, 9, 19, N=2500, ramp_time=ramp_time)
sns.lineplot(wave_train)
# Out:
# <Axes: >

# %%
sns.lineplot([surge,heave,pitch])
# Out:
# <Axes: >

# %%
type(surge)
# Out:
# list
